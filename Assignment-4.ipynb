# %% [markdown]
# # Q-1)

# %%
#Installing Necessary Libraries:-

import selenium
import pandas as pd
from selenium import webdriver 
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
#Let's Connect the driver:-
driver = webdriver.Chrome(r"C:\Users\SUVARCHALA\Downloads\chromedriver_win32.chromedriver.exe")

# %%
# Opening the Wkipidea with the following URL on automated chrome browser
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
Data=[]

# %%
#Scraping Data from the given Page
data_tags = driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr')
for i in data_tags[0:30]:
    data = i.text
    Data.append(data)

# %%
len(Data)
# Out:
# 30

# %%
df = pd.DataFrame(Data, columns=["Rank | Name | Artist | Upload Date | Views"])
df
# Out:
#            Rank | Name | Artist | Upload Date | Views
# 0   1. "Baby Shark Dance"[4] Pinkfong Baby Shark -...
# 1   2. "Despacito"[7] Luis Fonsi 8.04 January 12, ...
# 2   3. "Johny Johny Yes Papa"[14] LooLoo Kids 6.56...
# 3   4. "Bath Song"[15] Cocomelon – Nursery Rhymes ...
# 4   5. "Shape of You"[16] Ed Sheeran 5.87 January ...
# 5   6. "See You Again"[18] Wiz Khalifa 5.73 April ...
# 6   7. "Phonics Song with Two Words"[23] ChuChu TV...
# 7   8. "Uptown Funk"[24] Mark Ronson 4.78 November...
# 8   9. "Learning Colors – Colorful Eggs on a Farm"...
# 9   10. "Wheels on the Bus"[26] Cocomelon – Nurser...
# 10  11. "Gangnam Style"[27] Psy 4.63 July 15, 2012...
# 11  12. "Masha and the Bear – Recipe for Disaster"...
# 12  13. "Dame Tu Cosita"[33] El Chombo 4.17 April ...
# 13     14. "Sugar"[34] Maroon 5 3.80 January 14, 2015
# 14   15. "Roar"[35] Katy Perry 3.70 September 5, 2013
# 15  16. "Counting Stars"[36] OneRepublic 3.70 May ...
# ...

# %% [markdown]
# # Q-3)

# %%
#Let's Connect the driver:-
driver = webdriver.Chrome(r"C:\Users\SUVARCHALA\Downloads\chromedriver_win32.chromedriver.exe")

# %%
# Opening the Guru99 page on automated chrome browser
driver.get("https://www.guru99.com")

# %%
search = driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[2]/div[1]/div/ul[1]/li[3]/a")
search.click()

# %%
search = driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[2]")
search.click()

# %%
search = driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a/strong")
search.click()

# %%
Data=[]

# %%
data = driver.find_elements(By.XPATH,'//html/body/div[1]/div/div/div/main/div/article/div/div/p')
for i in data[0:41]:
    name = i.text
    Data.append(name)

# %%
len(Data)
# Out:
# 41

# %%
df = pd.DataFrame({'Exception_Name | Description':Data })
df
# Out:
#                          Exception_Name | Description
# 0   1. ElementNotVisibleException: This type of Se...
# 1   2. ElementNotSelectableException: This Seleniu...
# 2   3. NoSuchElementException: This Exception occu...
# 3   4. NoSuchFrameException: This Exception occurs...
# 4   5. NoAlertPresentException: This Exception occ...
# 5   6. NoSuchWindowException: This Exception occur...
# 6   7. StaleElementReferenceException: This Seleni...
# 7   8. SessionNotFoundException: The WebDriver is ...
# 8   9. TimeoutException: Thrown when there is not ...
# 9   10. WebDriverException: This Exception takes p...
# 10  11. ConnectionClosedException: This type of Ex...
# 11  12. ElementClickInterceptedException: The comm...
# 12  13. ElementNotInteractableException: This Sele...
# 13  14. ErrorInResponseException: This happens whi...
# 14  15. ErrorHandler.UnknownServerException: Excep...
# 15  16. ImeActivationFailedException: This expecta...
# ...

# %% [markdown]
# # Q-4)

# %%
import selenium
import pandas as pd
from selenium import webdriver 
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
#Let's Connect the driver:-
driver = webdriver.Chrome(r"C:\Users\SUVARCHALA\Downloads\chromedriver_win32.chromedriver.exe")

# %%
# Opening the Statistics times  page on automated chrome browser
driver.get("http://statisticstimes.com/")

# %%
search = driver.find_element(By.XPATH,"/html/body/div[2]/div[1]/div[2]/div[2]/button")
search.click()

# %%
search = driver.find_element(By.XPATH,"/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]")
search.click()

# %%
search = driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[2]/ul/li[1]/a ")
search.click()

# %%
Rank=[]
rank_tags = driver.find_elements(By.XPATH,'//td[@class="data1"]')
for i in rank_tags[0:33]:
    rank= i.text
    Rank.append(rank)

# %%
State=[]
state_tags = driver.find_elements(By.XPATH,'//td[@class="name"]')
for i in state_tags[0:33]:
    state= i.text
    State.append(state)

# %%
GSDP1=[]
gsdp1_tags = driver.find_elements(By.XPATH,'//div[@class="fwidth"][3]/div/div/table/tbody/tr/td[4]')
for i in gsdp1_tags[0:33]:
    gsdp1= i.text
    GSDP1.append(gsdp1)

# %%
GSDP2=[]
gsdp2_tags = driver.find_elements(By.XPATH,'//div[@class="fwidth"][3]/div/div/table/tbody/tr/td[3]')
for i in gsdp2_tags[0:33]:
    gsdp2= i.text
    GSDP2.append(gsdp2)

# %%
Share=[]
share_tags = driver.find_elements(By.XPATH,'//div[@class="fwidth"][3]/div/div/table/tbody/tr/td[5]')
for i in share_tags[0:33]:
    share= i.text
    Share.append(share)

# %%
GDP=[]
gdp_tags = driver.find_elements(By.XPATH,'//div[@class="fwidth"][3]/div/div/table/tbody/tr/td[6]')
for i in gdp_tags[0:33]:
    gdp= i.text
    GDP.append(gdp)

# %%
print(len(Rank),len(State),len(GSDP1),len(GSDP2),len(Share),len(GDP))
# Out:
# 33 33 33 33 33 33

# %%
df = pd.DataFrame({'RANK':Rank,'STATE':State,'GSDP(18-19)- at current prices':GSDP1,'GSDP(19-20)-at current prices':GSDP2,'Share(18-19)':Share,'GDP(18-19) $Billion':GDP})
df
# Out:
#    RANK                      STATE GSDP(18-19)- at current prices  \
# 0     1                Maharashtra                      2,632,792
# 1     2                 Tamil Nadu                      1,630,208
# 2     3              Uttar Pradesh                      1,584,764
# 3     4                    Gujarat                      1,502,899
# 4     5                  Karnataka                      1,493,127
# 5     6                West Bengal                      1,089,898
# 6     7                  Rajasthan                        942,586
# 7     8             Andhra Pradesh                        862,957
# 8     9                  Telangana                        861,031
# 9    10             Madhya Pradesh                        809,592
# 10   11                     Kerala                        781,653
# 11   12                      Delhi                        774,870
# 12   13                    Haryana                        734,163
# ...

# %% [markdown]
# # Q-5)

# %%
import selenium
import pandas as pd
from selenium import webdriver 
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
#Let's Connect the driver:-
driver = webdriver.Chrome(r"C:\Users\SUVARCHALA\Downloads\chromedriver_win32.chromedriver.exe")

# %%
# Opening the Naukri page on automated chrome browser
driver.get("https://github.com/")

# %%
search = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/button")
search.click()

# %%
search = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a")
search.click()

# %%
Repository_title=[]
title_tags = driver.find_elements(By.XPATH,'//span[@class="text-normal"]')
for i in title_tags[0:30]:
    title = i.text
    Repository_title.append(title)

# %%
len(Repository_title)
# Out:
# 25

# %%
print(Repository_title)
# Out:
# ['LAION-AI /', 'apple /', 'hehonghui /', 'AmruthPillai /', 'microfeed /', 'excalidraw /', 'TheOfficialFloW /', 'tesseract-ocr /', 'zhuowei /', 'novuhq /', 'timqian /', 'gabiduarte /', 'microsoft /', 'lencx /', 'facebook /', 'mouredev /', 'AmazingAng /', 'zas023 /', 'ChatGPT-Hackers /', 'bregman-arie /', 'zinclabs /', 'google /', '521xueweihan /', 'openai-php /', 'malkemit /']

# %%
Repository_Description=[]
description_tags = driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
for i in description_tags[0:30]:
    description = i.text
    Repository_Description.append(description)
Repository_Description.insert(0,None)

# %%
len(Repository_Description)
# Out:
# 25

# %%
print(Repository_Description)
# Out:
# [None, 'Stable Diffusion with Core ML on Apple Silicon', '经济学人(含音频)、纽约客、卫报、连线、大西洋月刊等英语杂志免费下载,支持epub、mobi、pdf格式, 每周更新', 'A one-of-a-kind resume builder that keeps your privacy in mind. Completely secure, customizable, portable, open-source and free forever. Try it out today!', 'a lightweight cms self-hosted on cloudflare, for podcasts, blogs, photos, videos, documents, and curated urls.', 'Virtual whiteboard for sketching hand-drawn like diagrams', 'WebKit+Kernel exploit chain for all PS Vita firmwares', 'Tesseract Open Source OCR Engine (main repository)', 'Proof-of-concept app to overwrite fonts on iOS using CVE-2022-46689.', 'The open-source notification infrastructure for products. Add a notification center for your React, Vue and Angular apps 🚀', '中文独立博客列表', 'Uma lista selecionada de conteúdos sobre liderança técnica, com preferência em conteúdos em português', 'Road detections from Microsoft Maps aerial imagery', '🤖 ChatGPT Desktop Application (Mac, Windows and Linux)', 'An open
# ...

# %%
Contributor_count=[]
contributor_tags = driver.find_elements(By.XPATH,'//div[@class="f6 color-fg-muted mt-2"]/a[2]')
for i in contributor_tags[0:30]:
    contributor = i.text
    Contributor_count.append(contributor)

# %%
len(Contributor_count)
# Out:
# 25

# %%
print(Contributor_count)
# Out:
# ['131', '185', '258', '1,111', '142', '3,219', '16', '8,301', '23', '977', '1,697', '95', '14', '156', '4,941', '201', '757', '503', '41', '1,462', '564', '187', '8,411', '20', '25']

# %%
Languages_used=[]
languages_used = driver.find_elements(By.XPATH,'//div[@class="f6 color-fg-muted mt-2"]/span[1]')
for i in languages_used[0:30]:
    languages = i.text
    Languages_used.append(languages)

# %%
len(Languages_used)
# Out:
# 25

# %%
print(Languages_used)
# Out:
# ['Python', 'Python', 'CSS', 'TypeScript', 'JavaScript', 'TypeScript', 'JavaScript', 'C++', 'Swift', 'TypeScript', 'JavaScript', 'Built by', 'Built by', 'Rust', 'C++', 'Built by', 'Solidity', 'Python', 'Go', 'Groovy', 'Go', 'Rust', 'Python', 'PHP', 'Python']

# %%
df = pd.DataFrame({'Repository_title':Repository_title,'Repository_Description':Repository_Description,'Contributor_count':Contributor_count,'Languages_used':Languages_used})
df
# Out:
#      Repository_title                             Repository_Description  \
# 0          LAION-AI /                                               None
# 1             apple /     Stable Diffusion with Core ML on Apple Silicon
# 2         hehonghui /  经济学人(含音频)、纽约客、卫报、连线、大西洋月刊等英语杂志免费下载,支持epub、mobi...
# 3      AmruthPillai /  A one-of-a-kind resume builder that keeps your...
# 4         microfeed /  a lightweight cms self-hosted on cloudflare, f...
# 5        excalidraw /  Virtual whiteboard for sketching hand-drawn li...
# 6   TheOfficialFloW /  WebKit+Kernel exploit chain for all PS Vita fi...
# 7     tesseract-ocr /  Tesseract Open Source OCR Engine (main reposit...
# 8           zhuowei /  Proof-of-concept app to overwrite fonts on iOS...
# 9            novuhq /  The open-source notification infrastructure fo...
# 10          timqian /                                           中文独立博客列表
# 11       gabiduarte /  Uma lista selecionada de conteúdos sobre lider...
# ...

# %% [markdown]
# # Q-7)

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
#Let's Connect to the driver:-
driver=webdriver.Chrome(r"C:\Users\SUVARCHALA\Downloads\chromedriver_win32.chromedriver.exe")

# %%
#Opening Naukri Page on automated Chrome Browser:
driver.get("https://www.naukri.com/hr-recruiters-consultants")

# %%
#Entering Skills as required in question
skill=driver.find_element(By.CLASS_NAME,"sugInp")
skill.send_keys("Datascience")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button")
search.click()

# %%
url=driver.find_elements(By.XPATH,'//a[@class="ellipsis"]')
url[0:36]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99f35ae9e6b05101a3dfbe429875f0f6", element="b1ed3c85-2f59-4d63-be0a-9e9bc7888a1c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99f35ae9e6b05101a3dfbe429875f0f6", element="082c583f-f218-4488-8275-e3895e353e27")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99f35ae9e6b05101a3dfbe429875f0f6", element="897b074d-cdd7-4c82-b651-5409f56b0d99")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99f35ae9e6b05101a3dfbe429875f0f6", element="ed736cc0-467c-4fb1-83e3-955f38b9ec7a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99f35ae9e6b05101a3dfbe429875f0f6", element="66461605-1fff-4376-888f-980fc9b36b0b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99f35ae9e6b05101a3dfbe429875f0f6", element="362b489c-5f08-433b-ba25-b9d3ecee380f")>,
# ...

# %%
for i in url[0:36]:
    print(i.get_attribute('href'))
# Out:
# https://www.naukri.com/recruiters/rosemary-3057500?xid=167241247443899900&xp=1
# https://www.naukri.com/flex-i-partners-recruiters?qsp=1
# https://www.naukri.com/recruiters/jatinnagpal-3214188?xid=167241247443899900&xp=2
# https://www.naukri.com/cvent-india-pvt-dot-ltd-dot-recruiters?qsp=1
# https://www.naukri.com/recruiters/alagesan-4454692?xid=167241247443899900&xp=3
# https://www.naukri.com/besant-technologies-recruiters?qsp=1
# https://www.naukri.com/recruiters/shanthi-3464014?xid=167241247443899900&xp=4
# https://www.naukri.com/iris-technologies-recruiters?qsp=1
# https://www.naukri.com/recruiters/dilip-3807510?xid=167241247443899900&xp=5
# https://www.naukri.com/greens-technologys-velachery-recruiters?qsp=1
# https://www.naukri.com/recruiters/sakshisingh-3217132?xid=167241247443899900&xp=6
# https://www.naukri.com/holcim-services-south-aisa-limited-recruiters?qsp=1
# https://www.naukri.com/recruiters/ravikumar-4686240?xid=167241247443899900&xp=7
# ...

# %%
Recruiters_info=[]
start=0
end=1

for page in range(start,end):
    recruiters_info=driver.find_elements(By.XPATH,'//div[@class="recInfo"]')
    for i in recruiters_info:
        Recruiters_info.append(i.text)
        
Recruiters_info
# Out:
# ['Rose Mary\nTalent Acquisition Specialist\nFlex i Partners\nBengaluru / Bangalore\nSkills/Roles I hire for :\nSenior Management, Information Technology, Facility Management, Indirect Taxation, Key Account Management, Asm, Deputy Manager, Zonal M, Zonal, Custom\n1 active jobs | Last active on 23-May-2018',
#  'Jatin Nagpal\nCompany Recruiter\nCvent India Pvt. Ltd.\nGurgaon\nSkills/Roles I hire for :\nNot Specified\n11 active jobs | Last active on 19-Sep-2019',
#  'Besant Technologies\nAssistant Manager\nBesant Technologies\nChennai\nSkills/Roles I hire for :\nTraining, Education\n4 active jobs | Last active on 19-Feb-2020',
#  'Shanthi\nCompany Recruiter\nIris Technologies\nChennai\nSkills/Roles I hire for :\nNot Specified\n0 active jobs | Last active on 13-Oct-2018',
#  'Dilip\nHR Executive\nGreens Technologys Velachery\nChennai\nSkills/Roles I hire for :\nHuman Resource Management, Software Development\n3 active jobs | Last active on 18-Sep-2018',
# ...

# %%
Recruiters_info=list(map(lambda x: x.replace('\n','-'),Recruiters_info))

# %%
df = pd.DataFrame(Recruiters_info, columns=["NAME - Designation - Company - Skilly they hire - location"])
df
# Out:
#    NAME - Designation - Company - Skilly they hire - location
# 0   Rose Mary-Talent Acquisition Specialist-Flex i...
# 1   Jatin Nagpal-Company Recruiter-Cvent India Pvt...
# 2   Besant Technologies-Assistant Manager-Besant T...
# 3   Shanthi-Company Recruiter-Iris Technologies-Ch...
# 4   Dilip-HR Executive-Greens Technologys Velacher...
# 5   Sakshi Singh-Company Recruiter-Holcim Services...
# 6   JTS-HR-Jignasa Techno Solutions Pvt Ltd-Hydera...
# 7   TA-Company Recruiter-Manipal Global Education ...
# 8   Niharika-HR-SaltSide-Bengaluru / Bangalore-Ski...
# 9   Chandra-Company Recruiter-A2Z CONTACTS PRIVATE...
# 10  HR-Talent Acquisition Manager-Afitech-Bengalur...
# 11  Joyce Roslin-HR IT Recruiter-Aegan Technologie...
# 12  Gargi Dave-Company Recruiter-HighRadius Techno...
# 13  Binary Fox-Company Recruiter-BINARY FOX SERVIC...
# 14  Sandeep Selvan-Sr Consultant-Wenger &amp; Wats...
# 15  Rajashekar-Talent Acquisition Executive-CBSI I...
# ...

# %% [markdown]
# # Q-8)

# %%
import selenium
import pandas as pd
from selenium import webdriver 
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
#Let's Connect to the driver:
driver = webdriver.Chrome(r"C:\Users\SUVARCHALA\Downloads\chromedriver_win32.chromedriver.exe")

# %%
#Opening the gurdian.com with automated browser
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
Book_Name=[]
book_tags = driver.find_elements(By.XPATH,"//div/table/tbody/tr/td[2]")
for i in book_tags[0:100]:
    book=i.text
    Book_Name.append(book)
Author_Name=[]
author_tags = driver.find_elements(By.XPATH,"//div/table/tbody/tr/td[3]")
for i in author_tags[0:100]:
    author=i.text
    Author_Name.append(author)
Volumes_Sold=[]
volumes_sold = driver.find_elements(By.XPATH,"//div/table/tbody/tr/td[4]")
for i in volumes_sold[0:100]:
    volumes=i.text
    Volumes_Sold.append(volumes)
Publisher=[]
publisher = driver.find_elements(By.XPATH,"//div/table/tbody/tr/td[5]")
for i in publisher[0:100]:
    publisherr = i.text
    Publisher.append(publisherr)
Genere=[]
genere=driver.find_elements(By.XPATH,"//div/table/tbody/tr/td[6]")
for i in genere[0:100]:
    generee=i.text
    Genere.append(generee)

# %%
print(len(Book_Name),len(Author_Name),len(Volumes_Sold),len(Publisher),len(Genere))
# Out:
# 100 100 100 100 100

# %%
df = pd.DataFrame({'Book Name':Book_Name,'Author Name':Author_Name,'Voumes Sold':Volumes_Sold,'Publisher':Publisher,'Genere':Genere})
df
# Out:
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Voumes Sold        Publisher                       Genere
# ...

# %% [markdown]
# # Q-6)

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException

# %%
#Let's Connect to the driver:-
driver=webdriver.Chrome(r"C:\Users\SUVARCHALA\Downloads\chromedriver_win32.chromedriver.exe")

# %%
driver.get("https://www.billboard.com/")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a")
search.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div[3]/header/div/div[3]/div/nav/ul/li[5]/a")
search.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div[3]/main/article/div[3]/div/div[1]/div[1]/p[1]/a")
search.click()

# %%
Data=[]

data_tags = driver.find_elements(By.XPATH,"//div[@class='o-chart-results-list-row-container']/ul/li[4]")
for i in data_tags[0:20]:
    songs = i.text
    Data.append(songs)

# %%
len(Data)
# Out:
# 20

# %%
print(Data)
# Out:
# ['Soul Of Varisu\nK.S. Chithra\n-\n1\n1', 'Deep End\nStray Kids\n-\n2\n1', "Dancing's Done\nAva Max\n-\n3\n1", 'Take My Breath\nNCT DREAM\n-\n4\n1', 'Walk With You\nNCT DREAM\n-\n5\n1', 'Stars And Raindrops\nStray Kids\n-\n6\n1', 'Doodle\nStray Kids\n-\n7\n1', 'Ice.Cream\nStray Kids\n-\n8\n1', 'Love Untold\nStray Kids\n-\n9\n1', 'Up All Night\nStray Kids\n-\n10\n1', 'Moon\nNCT DREAM\n-\n11\n1', 'Limbo\nStray Kids\n-\n12\n1', 'Mother Song\nSid Sriram\n-\n13\n1', 'Yet To Come\nBTS\n-\n1\n23', 'Mad Max\nLil Durk & Future\n-\n15\n1', 'Ditto\nNewJeans\n-\n16\n1', 'Run BTS\nBTS\n-\n2\n11', 'Sleepwalker\nAva Max\n-\n18\n1', 'Candy\nNCT DREAM\n-\n19\n1', 'Music Box : Reflection\nj-hope\n-\n20\n1']

# %%
Data = list(map(lambda x:x.replace('\n','--'),Data))

# %%
df = pd.DataFrame(Data, columns=["Song Name | Artist Name | Peak Rank | Weeks on board"])
df
# Out:
#    Song Name | Artist Name | Peak Rank | Weeks on board
# 0               Soul Of Varisu--K.S. Chithra-----1--1
# 1                       Deep End--Stray Kids-----2--1
# 2                    Dancing's Done--Ava Max-----3--1
# 3                  Take My Breath--NCT DREAM-----4--1
# 4                   Walk With You--NCT DREAM-----5--1
# 5            Stars And Raindrops--Stray Kids-----6--1
# 6                         Doodle--Stray Kids-----7--1
# 7                      Ice.Cream--Stray Kids-----8--1
# 8                    Love Untold--Stray Kids-----9--1
# 9                  Up All Night--Stray Kids-----10--1
# 10                          Moon--NCT DREAM-----11--1
# 11                        Limbo--Stray Kids-----12--1
# 12                  Mother Song--Sid Sriram-----13--1
# 13                         Yet To Come--BTS-----1--23
# 14               Mad Max--Lil Durk & Future-----15--1
# 15                          Ditto--NewJeans-----16--1
# ...

# %% [markdown]
# # Q-10)

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
#Let's Connect to Driver
driver=webdriver.Chrome(r"C:\Users\SUVARCHALA\Downloads\chromedriver_win32.chromedriver.exe")

# %%
#Opening UCI MachineLearning Repositories Page in browser
driver.get("https://archive.ics.uci.edu")

# %%
search=driver.find_element(By.XPATH,"/html/body/table[2]/tbody/tr/td/span/b/a")
search.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/table[1]/tbody/tr/td[2]/form/input[6]")
search.click()

# %%
url = driver.find_elements(By.XPATH,"//html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
url[0:622]
for i in url[0:622]:
    print(i.get_attribute('href'))
# Out:
# https://archive.ics.uci.edu/ml/datasets/Abalone
# https://archive.ics.uci.edu/ml/datasets/Adult
# https://archive.ics.uci.edu/ml/datasets/Annealing
# https://archive.ics.uci.edu/ml/datasets/Anonymous+Microsoft+Web+Data
# https://archive.ics.uci.edu/ml/datasets/Arrhythmia
# https://archive.ics.uci.edu/ml/datasets/Artificial+Characters
# https://archive.ics.uci.edu/ml/datasets/Audiology+%28Original%29
# https://archive.ics.uci.edu/ml/datasets/Audiology+%28Standardized%29
# https://archive.ics.uci.edu/ml/datasets/Auto+MPG
# https://archive.ics.uci.edu/ml/datasets/Automobile
# https://archive.ics.uci.edu/ml/datasets/Badges
# https://archive.ics.uci.edu/ml/datasets/Balance+Scale
# https://archive.ics.uci.edu/ml/datasets/Balloons
# https://archive.ics.uci.edu/ml/datasets/Breast+Cancer
# https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Original%29
# https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Prognostic%29
# ...

# %%
Dataset_Name=[]

start=0
end=1

for page in range(start,end):
    
    name=driver.find_elements(By.XPATH,'//html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a')
    
    for i in name:
        Dataset_Name.append(i.text)
Dataset_Name
# Out:
# ['Abalone',
#  'Adult',
#  'Annealing',
#  'Anonymous Microsoft Web Data',
#  'Arrhythmia',
#  'Artificial Characters',
#  'Audiology (Original)',
#  'Audiology (Standardized)',
#  'Auto MPG',
#  'Automobile',
#  'Badges',
#  'Balance Scale',
#  'Balloons',
#  'Breast Cancer',
#  'Breast Cancer Wisconsin (Original)',
#  'Breast Cancer Wisconsin (Prognostic)',
#  'Breast Cancer Wisconsin (Diagnostic)',
#  'Pittsburgh Bridges',
#  'Car Evaluation',
#  'Census Income',
#  'Chess (King-Rook vs. King-Knight)',
#  'Chess (King-Rook vs. King-Pawn)',
#  'Chess (King-Rook vs. King)',
#  'Chess (Domain Theories)',
#  'Bach Chorales',
#  'Connect-4',
#  'Credit Approval',
#  'Japanese Credit Screening',
#  'Computer Hardware',
#  'Contraceptive Method Choice',
#  'Covertype',
#  'Cylinder Bands',
#  'Dermatology',
#  'Diabetes',
#  'DGP2 - The Second Data Generation Program',
#  'Document Understanding',
#  'EBL Domain Theories',
#  'Echocardiogram',
#  'Ecoli',
#  'Flags',
# ...

# %%
len(Dataset_Name)
# Out:
# 622

# %%
Data_Type=[]

start=0
end=1

for page in range(start,end):
    
    datatype=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]/p")
    
    for i in datatype:
        Data_Type.append(i.text)

Data_Type
# Out:
# ['Data Types',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  ' ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Univariate, Text ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate, Data-Generator ',
#  'Multivariate ',
#  'Multivariate ',
#  'Domain-Theory ',
#  'Univariate, Time-Series ',
#  'Multivariate, Spatial ',
#  'Multivariate ',
#  'Multivariate, Domain-Theory ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate, Time-Series ',
#  'Data-Generator ',
#  ' ',
#  ' ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  ' ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
# ...

# %%
len(Data_Type)
# Out:
# 623

# %%
Data_Type.pop(0)
# Out:
# 'Data Types'

# %%
len(Data_Type)
# Out:
# 622

# %%
Task=[]

start=0
end=1

for page in range(start,end):
    
    task=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]/p")
    
    for i in task:
        Task.append(i.text)

Task
# Out:
# ['Default Task',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Recommender-Systems ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Regression ',
#  'Regression ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification, Regression ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  ' ',
#  ' ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Regression ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Function-Learning ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  ' ',
# ...

# %%
len(Task)
# Out:
# 623

# %%
Task.pop(0)
# Out:
# 'Default Task'

# %%
Attribute_Type=[]

start=0
end=1

for page in range(start,end):
    attribute=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]/p ")
    
    for i in attribute:
        Attribute_Type.append(i.text)
        
Attribute_Type
# Out:
# ['Attribute Types',
#  'Categorical, Integer, Real ',
#  'Categorical, Integer ',
#  'Categorical, Integer, Real ',
#  'Categorical ',
#  'Categorical, Integer, Real ',
#  'Categorical, Integer, Real ',
#  'Categorical ',
#  'Categorical ',
#  'Categorical, Real ',
#  'Categorical, Integer, Real ',
#  ' ',
#  'Categorical ',
#  'Categorical ',
#  'Categorical ',
#  'Integer ',
#  'Real ',
#  'Real ',
#  'Categorical, Integer ',
#  'Categorical ',
#  'Categorical, Integer ',
#  'Categorical, Integer ',
#  'Categorical ',
#  'Categorical, Integer ',
#  ' ',
#  'Categorical, Integer ',
#  'Categorical ',
#  'Categorical, Integer, Real ',
#  'Categorical, Real, Integer ',
#  'Integer ',
#  'Categorical, Integer ',
#  'Categorical, Integer ',
#  'Categorical, Integer, Real ',
#  'Categorical, Integer ',
#  'Categorical, Integer ',
#  'Real ',
#  ' ',
#  ' ',
#  'Categorical, Integer, Real ',
#  'Real ',
#  'Categorical, Integer ',
#  'Real ',
#  'Real ',
#  'Integer ',
#  'Categorical ',
# ...

# %%
Attribute_Type.pop(0)
# Out:
# 'Attribute Types'

# %%
len(Attribute_Type)
# Out:
# 622

# %%
Instances=[]

start=0
end=1

for page in range(start,end):
    instances=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]/p ")
    
    for i in instances:
        Instances.append(i.text)
        
Instances
# Out:
# ['# Instances',
#  '4177 ',
#  '48842 ',
#  '798 ',
#  '37711 ',
#  '452 ',
#  '6000 ',
#  '226 ',
#  '226 ',
#  '398 ',
#  '205 ',
#  '294 ',
#  '625 ',
#  '16 ',
#  '286 ',
#  '699 ',
#  '198 ',
#  '569 ',
#  '108 ',
#  '1728 ',
#  '48842 ',
#  ' ',
#  '3196 ',
#  '28056 ',
#  ' ',
#  '100 ',
#  '67557 ',
#  '690 ',
#  '125 ',
#  '209 ',
#  '1473 ',
#  '581012 ',
#  '512 ',
#  '366 ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '132 ',
#  '336 ',
#  '194 ',
#  '352 ',
#  '214 ',
#  '306 ',
#  '160 ',
#  '303 ',
#  '155 ',
#  '368 ',
#  ' ',
#  '2310 ',
#  '3279 ',
#  '351 ',
#  '150 ',
#  '7797 ',
#  '104 ',
#  '57 ',
#  ' ',
#  '24 ',
#  '20000 ',
#  '345 ',
#  ' ',
#  '32 ',
#  '148 ',
#  '209 ',
#  '528 ',
#  ' ',
#  '106 ',
#  '128 ',
#  '3190 ',
#  '432 ',
#  '202 ',
#  '2000 ',
#  '8124 ',
#  '476 ',
#  '6598 ',
#  '12960 ',
#  ' ',
#  '5473 ',
#  '5620 ',
#  '10992 ',
#  '90 ',
#  '339 ',
#  ' ',
#  ' ',
#  ' ',
#  '167 ',
#  '15 ',
#  '1389 ',
#  '307 ',
#  '47 ',
#  '23 ',
# ...

# %%
len(Instances)
# Out:
# 623

# %%
Instances.pop(0)
# Out:
# '# Instances'

# %%
Attributes=[]

start=0
end=1

for page in range(start,end):
    attributes=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]/p")
    
    for i in attributes:
        Attributes.append(i.text)
        
Attributes
# Out:
# ['# Attributes',
#  '8 ',
#  '14 ',
#  '38 ',
#  '294 ',
#  '279 ',
#  '7 ',
#  ' ',
#  '69 ',
#  '8 ',
#  '26 ',
#  '1 ',
#  '4 ',
#  '4 ',
#  '9 ',
#  '10 ',
#  '34 ',
#  '32 ',
#  '13 ',
#  '6 ',
#  '14 ',
#  '22 ',
#  '36 ',
#  '6 ',
#  ' ',
#  '6 ',
#  '42 ',
#  '15 ',
#  ' ',
#  '9 ',
#  '9 ',
#  '54 ',
#  '39 ',
#  '33 ',
#  '20 ',
#  ' ',
#  ' ',
#  ' ',
#  '12 ',
#  '8 ',
#  '30 ',
#  ' ',
#  '10 ',
#  '3 ',
#  '5 ',
#  '75 ',
#  '19 ',
#  '27 ',
#  ' ',
#  '19 ',
#  '1558 ',
#  '34 ',
#  '4 ',
#  '617 ',
#  '12 ',
#  '16 ',
#  '7 ',
#  '4 ',
#  '16 ',
#  '7 ',
#  ' ',
#  '56 ',
#  '18 ',
#  '8 ',
#  '22 ',
#  ' ',
#  '58 ',
#  ' ',
#  '61 ',
#  '7 ',
#  ' ',
#  '649 ',
#  '22 ',
#  '168 ',
#  '168 ',
#  '8 ',
#  ' ',
#  '10 ',
#  '64 ',
#  '16 ',
#  '8 ',
#  '17 ',
#  ' ',
#  ' ',
#  '72 ',
#  '4 ',
#  '6 ',
#  '10 ',
#  '35 ',
#  '35 ',
#  '4 ',
#  '102 ',
#  '57 ',
#  '22 ',
#  '44 ',
#  '45 ',
#  ' ',
#  ' ',
#  '5 ',
#  '9 ',
#  '21 ',
#  '32 ',
#  '17 ',
#  '16 ',
# ...

# %%
len(Attributes)
# Out:
# 623

# %%
Attributes.pop(0)
# Out:
# '# Attributes'

# %%
Year=[]

start=0
end=1

for page in range(start,end):
    year=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]/p ")
    
    for i in year:
        Year.append(i.text)
        
Year
# Out:
# ['Year',
#  '1995 ',
#  '1996 ',
#  ' ',
#  '1998 ',
#  '1998 ',
#  '1992 ',
#  '1987 ',
#  '1992 ',
#  '1993 ',
#  '1987 ',
#  '1994 ',
#  '1994 ',
#  ' ',
#  '1988 ',
#  '1992 ',
#  '1995 ',
#  '1995 ',
#  '1990 ',
#  '1997 ',
#  '1996 ',
#  '1988 ',
#  '1989 ',
#  '1994 ',
#  ' ',
#  ' ',
#  '1995 ',
#  ' ',
#  '1992 ',
#  '1987 ',
#  '1997 ',
#  '1998 ',
#  '1995 ',
#  '1998 ',
#  ' ',
#  ' ',
#  '1994 ',
#  ' ',
#  '1989 ',
#  '1996 ',
#  '1990 ',
#  '1990 ',
#  '1987 ',
#  '1999 ',
#  '1989 ',
#  '1988 ',
#  '1988 ',
#  '1989 ',
#  ' ',
#  '1990 ',
#  '1998 ',
#  '1989 ',
#  '1988 ',
#  '1994 ',
#  '1990 ',
#  '1988 ',
#  '1988 ',
#  '1990 ',
#  '1991 ',
#  '1990 ',
#  ' ',
#  '1992 ',
#  '1988 ',
#  '1990 ',
#  '1996 ',
#  '1995 ',
#  '1990 ',
#  ' ',
#  '1992 ',
#  '1992 ',
#  '1994 ',
#  ' ',
#  '1987 ',
#  '1994 ',
#  '1994 ',
#  '1997 ',
#  '1991 ',
#  '1995 ',
#  '1998 ',
#  '1998 ',
#  '1993 ',
#  '1988 ',
#  ' ',
#  ' ',
#  '1992 ',
#  '1993 ',
#  '1988 ',
#  '1989 ',
# ...

# %%
len(Year)
# Out:
# 623

# %%
Year.pop(0)
# Out:
# 'Year'

# %%
df =pd.DataFrame({'Dataset Name':Dataset_Name,'Data Type': Data_Type,'Task': Task,'Attribute Types':Attribute_Type,'No.Instances':Instances,'No.Attributes':Attributes,'Year':Year})
df
# Out:
#                                           Dataset Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data Type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...

# %% [markdown]
# # Q-9)

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
#Let's connect to the driver:
driver=webdriver.Chrome(r"C:\Users\SUVARCHALA\Downloads\chromedriver_win32.chromedriver.exe")

# %%
#opening Imdb page in automated Chrome browser:
driver.get("https://www.imdb.com/list/ls095964455")

# %%
#Getting URLs:
url=driver.find_elements(By.XPATH,"/html/body/div[2]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/h3/a ")
url[0:100]
for i in url:
    print(i.get_attribute('href'))
# Out:
# https://www.imdb.com/title/tt0944947/?ref_=ttls_li_tt
# https://www.imdb.com/title/tt4574334/?ref_=ttls_li_tt
# https://www.imdb.com/title/tt1520211/?ref_=ttls_li_tt
# https://www.imdb.com/title/tt1837492/?ref_=ttls_li_tt
# https://www.imdb.com/title/tt2661044/?ref_=ttls_li_tt
# https://www.imdb.com/title/tt2372162/?ref_=ttls_li_tt
# https://www.imdb.com/title/tt5420376/?ref_=ttls_li_tt
# https://www.imdb.com/title/tt0413573/?ref_=ttls_li_tt
# https://www.imdb.com/title/tt3107288/?ref_=ttls_li_tt
# https://www.imdb.com/title/tt2193021/?ref_=ttls_li_tt
# https://www.imdb.com/title/tt6468322/?ref_=ttls_li_tt
# https://www.imdb.com/title/tt0898266/?ref_=ttls_li_tt
# https://www.imdb.com/title/tt2085059/?ref_=ttls_li_tt
# https://www.imdb.com/title/tt1475582/?ref_=ttls_li_tt
# https://www.imdb.com/title/tt2306299/?ref_=ttls_li_tt
# https://www.imdb.com/title/tt1578873/?ref_=ttls_li_tt
# https://www.imdb.com/title/tt1405406/?ref_=ttls_li_tt
# ...

# %%
TV_Show_Name=[]

start=0
end=1

for page in range(start,end):
    name=driver.find_elements(By.XPATH,"/html/body/div[2]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/h3/a")
    
    for i in name:
        TV_Show_Name.append(i.text)
        
TV_Show_Name
# Out:
# ['Game of Thrones',
#  'Stranger Things',
#  'The Walking Dead',
#  '13 Reasons Why',
#  'The 100',
#  'Orange Is the New Black',
#  'Riverdale',
#  "Grey's Anatomy",
#  'The Flash',
#  'Arrow',
#  'Money Heist',
#  'The Big Bang Theory',
#  'Black Mirror',
#  'Sherlock',
#  'Vikings',
#  'Pretty Little Liars',
#  'The Vampire Diaries',
#  'American Horror Story',
#  'Breaking Bad',
#  'Lucifer',
#  'Supernatural',
#  'Prison Break',
#  'How to Get Away with Murder',
#  'Teen Wolf',
#  'The Simpsons',
#  'Once Upon a Time',
#  'Narcos',
#  'Daredevil',
#  'Friends',
#  'How I Met Your Mother',
#  'Suits',
#  'Mr. Robot',
#  'The Originals',
#  'Supergirl',
#  'Gossip Girl',
#  'Sense8',
#  'Gotham',
#  'Westworld',
#  'Jessica Jones',
#  'Modern Family',
#  'Rick and Morty',
#  'Shadowhunters',
#  'The End of the F***ing World',
#  'House of Cards',
#  'Dark',
#  'Elite',
#  'Sex Education',
#  'Shameless',
#  'New Girl',
#  'Agents of S.H.I.E.L.D.',
#  'You',
#  'Dexter',
# ...

# %%
len(TV_Show_Name)
# Out:
# 100

# %%
Year_Span=[]

start=0
end=1

for page in range(start,end):
    span=driver.find_elements(By.XPATH,'/html/body/div[2]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/h3/span[2]')
    
    for i in span:
        Year_Span.append(i.text)          
        
Year_Span
# Out:
# ['(2011–2019)',
#  '(2016– )',
#  '(2010–2022)',
#  '(2017–2020)',
#  '(2014–2020)',
#  '(2013–2019)',
#  '(2017– )',
#  '(2005– )',
#  '(2014–2023)',
#  '(2012–2020)',
#  '(2017–2021)',
#  '(2007–2019)',
#  '(2011–2019)',
#  '(2010–2017)',
#  '(2013–2020)',
#  '(2010–2017)',
#  '(2009–2017)',
#  '(2011– )',
#  '(2008–2013)',
#  '(2016–2021)',
#  '(2005–2020)',
#  '(2005–2017)',
#  '(2014–2020)',
#  '(2011–2017)',
#  '(1989– )',
#  '(2011–2018)',
#  '(2015–2017)',
#  '(2015–2018)',
#  '(1994–2004)',
#  '(2005–2014)',
#  '(2011–2019)',
#  '(2015–2019)',
#  '(2013–2018)',
#  '(2015–2021)',
#  '(2007–2012)',
#  '(2015–2018)',
#  '(2014–2019)',
#  '(2016–2022)',
#  '(2015–2019)',
#  '(2009–2020)',
#  '(2013– )',
#  '(2016–2019)',
#  '(2017–2019)',
#  '(2013–2018)',
#  '(2017–2020)',
#  '(2018– )',
#  '(2019– )',
#  '(2011–2021)',
#  '(2011–2018)',
#  '(2013–2020)',
#  '(2018– )',
#  '(2006–2013)',
#  '(2015– )',
#  '(1999– )',
#  '(2013– )',
#  '(2004–2010)',
#  '(2013–2022)',
# ...

# %%
len(Year_Span)
# Out:
# 100

# %%
Genere=[]

start=0
end=1

for page in range(start,end):
    genere=driver.find_elements(By.XPATH,"/html/body/div[2]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/p[1]/span[5]")
    
    for i in genere:
        Genere.append(i.text)

Genere
# Out:
# ['Action, Adventure, Drama',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Drama, Mystery, Thriller',
#  'Drama, Mystery, Sci-Fi',
#  'Comedy, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Drama, Romance',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Crime',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Drama, Mystery, Sci-Fi',
#  'Crime, Drama, Mystery',
#  'Action, Adventure, Drama',
#  'Drama, Mystery, Romance',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Sci-Fi',
#  'Crime, Drama, Thriller',
#  'Crime, Drama, Fantasy',
#  'Drama, Fantasy, Horror',
#  'Action, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Action, Drama, Fantasy',
#  'Animation, Comedy',
#  'Adventure, Fantasy, Romance',
#  'Biography, Crime, Drama',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Comedy, Romance',
#  'Comedy, Drama',
#  'Crime, Drama, Thriller',
#  'Drama, Fantasy, Horror',
#  'Action, Adventure, Drama',
#  'Drama, Romance',
#  'Drama, Mystery, Sci-Fi',
# ...

# %%
len(Genere)
# Out:
# 100

# %%
Run_time=[]

start=0
end=1

for page in range(start,end):
    runtime = driver.find_elements(By.XPATH,"/html/body/div[2]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/p[1]/span[3] ")
    
    for i in runtime:
        Run_time.append(i.text)           
        
Run_time
# Out:
# ['57 min',
#  '51 min',
#  '44 min',
#  '60 min',
#  '43 min',
#  '59 min',
#  '45 min',
#  '41 min',
#  '43 min',
#  '42 min',
#  '70 min',
#  '22 min',
#  '60 min',
#  '88 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '60 min',
#  '49 min',
#  '42 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '41 min',
#  '22 min',
#  '60 min',
#  '49 min',
#  '54 min',
#  '22 min',
#  '22 min',
#  '44 min',
#  '49 min',
#  '45 min',
#  '43 min',
#  '42 min',
#  '60 min',
#  '42 min',
#  '62 min',
#  '56 min',
#  '22 min',
#  '23 min',
#  '42 min',
#  '25 min',
#  '51 min',
#  '60 min',
#  '60 min',
#  '45 min',
#  '46 min',
#  '22 min',
#  '45 min',
#  '45 min',
#  '53 min',
#  '44 min',
#  '22 min',
#  '43 min',
#  '44 min',
#  '60 min',
#  '44 min',
#  '42 min',
#  '44 min',
#  '55 min',
#  '42 min',
#  '42 min',
#  '60 min',
#  '60 min',
#  '41 min',
#  '60 min',
#  '44 min',
#  '22 min',
#  '22 min',
#  '43 min',
#  '60 min',
#  '55 min',
#  '60 min',
#  '45 min',
#  '46 min',
# ...

# %%
len(Run_time)
# Out:
# 100

# %%
Ratings=[]

start=0
end=1

for page in range(start,end):
    ratings = driver.find_elements(By.XPATH,"/html/body/div[2]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/div[1]/div[1]/span[2] ")
    
    for i in ratings:
        Ratings.append(i.text)              
Ratings
# Out:
# ['9.2',
#  '8.7',
#  '8.1',
#  '7.5',
#  '7.6',
#  '8.1',
#  '6.6',
#  '7.6',
#  '7.6',
#  '7.5',
#  '8.2',
#  '8.2',
#  '8.8',
#  '9.1',
#  '8.5',
#  '7.4',
#  '7.7',
#  '8',
#  '9.5',
#  '8.1',
#  '8.4',
#  '8.3',
#  '8.1',
#  '7.7',
#  '8.7',
#  '7.7',
#  '8.8',
#  '8.6',
#  '8.9',
#  '8.3',
#  '8.5',
#  '8.6',
#  '8.3',
#  '6.2',
#  '7.5',
#  '8.2',
#  '7.8',
#  '8.5',
#  '7.9',
#  '8.5',
#  '9.1',
#  '6.5',
#  '8.1',
#  '8.7',
#  '8.7',
#  '7.3',
#  '8.4',
#  '8.6',
#  '7.8',
#  '7.5',
#  '7.7',
#  '8.7',
#  '6.8',
#  '8.2',
#  '8',
#  '8.3',
#  '8.8',
#  '8.7',
#  '6.7',
#  '8.3',
#  '8.3',
#  '7.3',
#  '6.8',
#  '8.4',
#  '7.4',
#  '8.1',
#  '7.9',
#  '6.8',
#  '8.7',
#  '8.4',
#  '6.5',
#  '7.9',
#  '8.9',
#  '7.8',
#  '7.6',
#  '8.9',
#  '8.1',
#  '8.5',
#  '8.3',
#  '7.3',
#  '8.7',
#  '8.2',
#  '6.4',
#  '6.3',
#  '8.6',
#  '7.8',
#  '7.3',
#  '7.7',
#  '7.2',
#  '8.5',
#  '6.5',
#  '8.1',
#  '8.7',
#  '9.4',
#  '7.8',
#  '7.4',
#  '7.8',
#  '8.1',
#  '7.1',
#  '8.6']

# %%
len(Ratings)
# Out:
# 100

# %%
Votes=[]

start=0
end=1

for page in range(start,end):
    votes=driver.find_elements(By.XPATH,"/html/body/div[2]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]/div/div[2]/p[4]/span[2] ")
    
    for i in votes:
        Votes.append(i.text)                        
        
Votes
# Out:
# ['2,099,515',
#  '1,189,757',
#  '993,882',
#  '294,127',
#  '253,250',
#  '303,846',
#  '146,000',
#  '310,660',
#  '347,187',
#  '432,697',
#  '478,604',
#  '810,210',
#  '549,095',
#  '927,888',
#  '534,017',
#  '168,550',
#  '323,473',
#  '320,984',
#  '1,885,333',
#  '326,165',
#  '447,496',
#  '537,333',
#  '152,933',
#  '149,699',
#  '408,844',
#  '226,014',
#  '423,886',
#  '442,314',
#  '997,641',
#  '685,512',
#  '412,609',
#  '389,091',
#  '137,155',
#  '124,701',
#  '176,161',
#  '155,385',
#  '231,454',
#  '506,770',
#  '215,755',
#  '432,810',
#  '525,439',
#  '64,452',
#  '192,549',
#  '505,842',
#  '390,461',
#  '80,463',
#  '283,187',
#  '244,541',
#  '226,096',
#  '218,003',
#  '243,305',
#  '727,026',
#  '130,966',
#  '341,658',
#  '250,941',
#  '555,221',
#  '551,423',
#  '466,723',
#  '61,361',
#  '111,796',
#  '342,991',
#  '74,626',
#  '105,512',
#  '239,401',
#  '96,426',
#  '96,274',
#  '51,485',
#  '149,364',
#  '370,788',
#  '318,379',
#  '107,249',
# ...

# %%
len(Votes)
# Out:
# 100

# %%
df=pd.DataFrame({'Name':TV_Show_Name,'Year Span':Year_Span,'Genere':Genere,'Run time':Run_time,'Ratings':Ratings,'Votes':Votes })
df
# Out:
#                               Name    Year Span                    Genere  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run time Ratings      Votes
# 0    57 min     9.2  2,099,515
# ...

# %% [markdown]
# # Q-2)

# %%
import selenium
import pandas as pd
from selenium import webdriver 
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
#Let's Connect the driver:-
driver = webdriver.Chrome(r"C:\Users\SUVARCHALA\Downloads\chromedriver_win32.chromedriver.exe")

# %%
# Opening the International Cricket Matches from page on automated chrome browser
driver.get("https://www.bcci.tv/")

# %%
search = driver.find_element(By.XPATH,"/html/body/div[5]/div/div[2]/div/div[2]/div/div[1]/div[2]/a")
search.click()

# %%
search = driver.find_element(By.XPATH,'//div[@class="col-lg-2 col-md-2 col-sm-12"]')
search.click()

# %%
search = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div/div/div/div[2]/div[2]/div/div[3]/div/div[2]/div[3]')
search.click()

# %%
Match_title=[]
start = 0
end=1

for page in range(start,end):
    
    title = driver.find_elements(By.XPATH,"/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div[1]/div/div/div[3]")
    
    for i in title:
        Match_title.append(i.text)

# %%
len(Match_title)
# Out:
# 8

# %%
Match_title=list(map(lambda x: x.replace('\n','-'),Match_title))

# %%
Series=[]
start=0
end=1

for page in range(start,end):
    
    series=driver.find_elements(By.XPATH,"/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div[1]/div/div/div[1]/h5[2]/span")
    
    for i in series:
        Series.append(i.text)

# %%
len(Series)
# Out:
# 8

# %%
Place=[]

start=0
end=1

for page in range(start,end):
    place=driver.find_elements(By.XPATH,"/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div/div/div/div[4]/div ")
    
    for i in place:
        Place.append(i.text)

# %%
len(Place)
# Out:
# 8

# %%
Date=[]

start=0
end=1

for page in range(start,end):
    date=driver.find_elements(By.XPATH,"/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div/div/div/div[1]/div/div[1]/h5 ")
    
    for i in date:
        Date.append(i.text)

# %%
len(Date)
# Out:
# 8

# %%
Time=[]

start=0
end=1

for page in range(start,end):
    time=driver.find_elements(By.XPATH,"/html/body/div[2]/div[2]/div/div/div/div[2]/div[3]/div/div/div/div[1]/div/div[2]/h5 ")
    
    for i in time:
        Time.append(i.text)

# %%
len(Time)
# Out:
# 8

# %%
df=pd.DataFrame({'Match_title':Match_title,'Series':Series,'Place':Place,'Date':Date,'Time':Time })
df
# Out:
#             Match_title                                        Series  \
# 0    India-vs-Sri Lanka    SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
# 1    India-vs-Sri Lanka    SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
# 2    India-vs-Sri Lanka    SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
# 3  India-vs-New Zealand  NEW ZEALAND TOUR OF INDIA ODI SERIES 2022-23
# 4  India-vs-New Zealand  NEW ZEALAND TOUR OF INDIA ODI SERIES 2022-23
# 5  India-vs-New Zealand  NEW ZEALAND TOUR OF INDIA ODI SERIES 2022-23
# 6    India-vs-Australia    AUSTRALIA TOUR OF INDIA ODI SERIES 2022-23
# 7    India-vs-Australia    AUSTRALIA TOUR OF INDIA ODI SERIES 2022-23
#
#                                                Place         Date         Time
# 0      1st ODI - Barsapara Cricket Stadium, Guwahati  10 JAN 2023  1:30 PM IST
# 1                    2nd ODI - Eden Gardens, Kolkata  12 JAN 2023  1:30 PM IST
# 2  3rd ODI - Greenfield International Stadium, Th...  15 JAN 2023  1:30 PM IST
# ...
